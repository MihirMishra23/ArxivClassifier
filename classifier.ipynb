# %%
import torch
import numpy as np
import dask.dataframe as dd
import csv
import os
import pandas as pd
import sklearn.preprocessing as skl_prep
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %%
# Path to your JSON file
json_file_path = 'train_major_cats_full.json'

# Load the JSON file into a Dask DataFrame
ddf = dd.read_json(json_file_path)

# %%
ddf.head()
# Out:
#      paper_id  version  yymm              created  \
# 0   1110.1547        1  1110  2011-10-07T14:37:25
# 1   1107.3567        1  1107  2011-07-18T20:18:43
# 2  1610.06216        1  1610  2016-10-19T20:59:41
# 3   1309.3106        1  1309  2013-09-12T10:51:27
# 4   1410.2451        2  1410  2015-03-30T18:19:30
#
#                                                title  \
# 0  The impact of CCD radiation damage on Gaia ast...
# 1  Polypropylene Embedded Metal-Mesh Broadband Ac...
# 2  A Versatile Technique to Enable sub-milli-Kelv...
# 3  Influence of aerosols from biomass burning on ...
# 4  Parque Astron\'omico de Atacama: An ideal site...
#
#                                abs_categories  \
# 0                                 astro-ph.IM
# 1  astro-ph.IM physics.ins-det physics.optics
# 2                     astro-ph.IM astro-ph.EP
# 3                                 astro-ph.IM
# 4                                 astro-ph.IM
#
#                                             abstract prime_category  \
# 0  The Gaia mission has been designed to perform ...    astro-ph.IM
# 1  We describe a novel multi-layered metal mesh a...    astro-ph.IM
# 2  Insufficient instrument thermo-mechanical stab...    astro-ph.IM
# 3  During the last decade, imaging atmospheric Ch...    astro-ph.IM
# 4  The area of Chajnantor, at more than 5000 mete...    astro-ph.IM
#
#   major_category                                           fulltext
# 0       astro-ph  Mon. Not. R. Astron. Soc. 000, 1 -- 21 (2011)
# ...
# 1       astro-ph
# Polypropylene Embedded Metal-Mesh Broadband
#
# ...
# 2       astro-ph  ACCEPTED FOR PUBLICATION IN APJ
# Preprint types...
# 3       astro-ph
# 33RD INTERNATIONAL COSMIC RAY CONFERENCE, RIO...
# 4       astro-ph
# Parque Astron´omico de Atacama: An Ideal Site...
